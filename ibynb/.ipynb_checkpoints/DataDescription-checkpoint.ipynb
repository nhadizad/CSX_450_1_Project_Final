# %%
options(repr.plot.width=12, repr.plot.height=6)

# %%
CTypes <- c("factor","numeric","numeric","numeric","numeric","numeric","numeric","numeric","numeric")
CNames <- c("Sex","Length","Diameter","Height","WholeWeigth","ShuckedWeigth","VisceraWeight","ShellWeight","Rings")
abalonedata <- read.csv("../data/abalone.csv", header = FALSE, colClasses=CTypes, col.names=CNames)

# %%
dim(abalonedata)
# Out:
# [1] 4177    9

# %%
summary(abalonedata)
# Out:
#  Sex          Length         Diameter          Height        WholeWeigth
#  F:1307   Min.   :0.075   Min.   :0.0550   Min.   :0.0000   Min.   :0.0020
#  I:1342   1st Qu.:0.450   1st Qu.:0.3500   1st Qu.:0.1150   1st Qu.:0.4415
#  M:1528   Median :0.545   Median :0.4250   Median :0.1400   Median :0.7995
#           Mean   :0.524   Mean   :0.4079   Mean   :0.1395   Mean   :0.8287
#           3rd Qu.:0.615   3rd Qu.:0.4800   3rd Qu.:0.1650   3rd Qu.:1.1530
#           Max.   :0.815   Max.   :0.6500   Max.   :1.1300   Max.   :2.8255
#  ShuckedWeigth    VisceraWeight     ShellWeight         Rings
#  Min.   :0.0010   Min.   :0.0005   Min.   :0.0015   Min.   : 1.000
#  1st Qu.:0.1860   1st Qu.:0.0935   1st Qu.:0.1300   1st Qu.: 8.000
#  Median :0.3360   Median :0.1710   Median :0.2340   Median : 9.000
#  Mean   :0.3594   Mean   :0.1806   Mean   :0.2388   Mean   : 9.934
#  3rd Qu.:0.5020   3rd Qu.:0.2530   3rd Qu.:0.3290   3rd Qu.:11.000
# ...

# %%
object.size(abalonedata)
# Out:
# 286232 bytes

# %%
head(abalonedata)
# Out:
#   Sex Length Diameter Height WholeWeigth ShuckedWeigth VisceraWeight
# 1 M   0.455  0.365    0.095  0.5140      0.2245        0.1010
# 2 M   0.350  0.265    0.090  0.2255      0.0995        0.0485
# 3 F   0.530  0.420    0.135  0.6770      0.2565        0.1415
# 4 M   0.440  0.365    0.125  0.5160      0.2155        0.1140
# 5 I   0.330  0.255    0.080  0.2050      0.0895        0.0395
# 6 I   0.425  0.300    0.095  0.3515      0.1410        0.0775
#   ShellWeight Rings
# 1 0.150       15
# 2 0.070        7
# 3 0.210        9
# 4 0.155       10
# 5 0.055        7
# 6 0.120        8

# %%
sapply(abalonedata,mode)
sapply(abalonedata,typeof)
# Out:
#           Sex        Length      Diameter        Height   WholeWeigth
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
# ShuckedWeigth VisceraWeight   ShellWeight         Rings
#     "numeric"     "numeric"     "numeric"     "numeric"
#           Sex        Length      Diameter        Height   WholeWeigth
#     "integer"      "double"      "double"      "double"      "double"
# ShuckedWeigth VisceraWeight   ShellWeight         Rings
#      "double"      "double"      "double"      "double"

# %%
str(abalonedata)
# Out:
# 'data.frame':	4177 obs. of  9 variables:
#  $ Sex          : Factor w/ 3 levels "F","I","M": 3 3 1 3 2 2 1 1 3 1 ...
#  $ Length       : num  0.455 0.35 0.53 0.44 0.33 0.425 0.53 0.545 0.475 0.55 ...
#  $ Diameter     : num  0.365 0.265 0.42 0.365 0.255 0.3 0.415 0.425 0.37 0.44 ...
#  $ Height       : num  0.095 0.09 0.135 0.125 0.08 0.095 0.15 0.125 0.125 0.15 ...
#  $ WholeWeigth  : num  0.514 0.226 0.677 0.516 0.205 ...
#  $ ShuckedWeigth: num  0.2245 0.0995 0.2565 0.2155 0.0895 ...
#  $ VisceraWeight: num  0.101 0.0485 0.1415 0.114 0.0395 ...
#  $ ShellWeight  : num  0.15 0.07 0.21 0.155 0.055 0.12 0.33 0.26 0.165 0.32 ...
#  $ Rings        : num  15 7 9 10 7 8 20 16 9 19 ...

# %%
levels(abalonedata$Sex)
# Out:
# [1] "F" "I" "M"

# %%
hist(abalonedata$Rings)
# Out:
# Plot with title “Histogram of abalonedata$Rings”

# %%
hist(abalonedata$Diameter)
# Out:
# Plot with title “Histogram of abalonedata$Diameter”

# %%
hist(abalonedata$WholeWeigth)
# Out:
# Plot with title “Histogram of abalonedata$WholeWeigth”

# %%
hist(abalonedata$Height)
# Out:
# Plot with title “Histogram of abalonedata$Height”

# %%
pairs(abalonedata[2:8], pch = 21,bg = c("red", "green", "blue")[unclass(abalonedata$Sex)])
# Out:
# plot without title

# %%
plot(abalonedata$Length, abalonedata$Diameter, pch = 21,bg = c("red", "green", "blue")[unclass(abalonedata$Sex)])
# Out:
# plot without title

# %%
plot(abalonedata$WholeWeigth, abalonedata$Rings, pch = 21,bg = c("red", "green", "blue")[unclass(abalonedata$Sex)])
# Out:
# plot without title

# %%
plot(abalonedata$Diameter, abalonedata$Rings, pch = 21,bg = c("red", "green", "blue")[unclass(abalonedata$Sex)])
# Out:
# plot without title

# %%
library("caret")
# Out:
# Loading required package: lattice
# Loading required package: ggplot2

# %%
abalonefeatures <- abalonedata[,2:9]
abaloneclass <- abalonedata[,1]

# %%
featurePlot(x=abalonefeatures, y=abaloneclass, plot="box")
# Out:
# plot without title
